# %% [markdown]
# # Iris Flowers Classification in ML

# %% [markdown]
# # Author-Gaurikumar Shinde
# ### Data Science Intern @LGM
# ### Task - 01
# ### Task - Iris Flowers Classification ML Project

# %%
# Importing the libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import os

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# Reading dataset

# %%
df=pd.read_csv("C:/Users/Rushikesh/Desktop/Iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: species, dtype: int64

# %% [markdown]
# ## Visualization

# %%
# Data description through colormap

# %%
df.describe().plot(kind ="area",fontsize=20, figsize=(15,5),table=True,colormap="rainbow")
plt.xlabel('Statistics')
plt.ylabel('Value')
plt.title("General statistics for Iris Dataset")
plt.show()

# %%
#Catplot

# %%
sns.catplot(x = 'species', hue = 'species', kind = 'count', data = df)

# %%
# Bar plot- Species Vs Petal Width

# %%
plt.bar(df['species'],df['petal_width'])
# Out:
# <BarContainer object of 150 artists>

# %%
# Pie chart

# %%
a=plt.subplots(1,1,figsize=(20,8))
df     ['species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1F%%',shadow=True,figsize=(15,5))
plt.title("Iris Species %")
plt.show()

# %%
# Joint plot

# %%
fig=sns.jointplot(x='sepal_length',y='sepal_width',data=df,color='maroon')
pass

# %%
fig=sns.jointplot(x='sepal_length',y='sepal_width',kind='hex',data=df,color='orange')

# %%
fig=sns.jointplot(x='sepal_length',y='sepal_width',kind='kde',data=df,color='black')

# %%
# FacetGrid plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sns.FacetGrid(df,hue='species',size=7)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()
pass
# Out:
# E:\anaconda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Whisker plot/Box plot

# %%
plt.figure(figsize=(18,10))
plt.subplot(2,2,1)
sns.boxplot(x='species',y='petal_length',data=df)
plt.subplot(2,2,2)
sns.boxplot(x='species',y='petal_width',data=df)
plt.subplot(2,2,3)
sns.boxplot(x='species',y='sepal_length',data=df)
plt.subplot(2,2,4)
sns.boxplot(x='species',y='sepal_width',data=df)
plt.show()

# %%
# Strip plot

# %%
fig=plt.gcf()
fig.set_size_inches(8,8)
fig=sns.stripplot(x='species',y='sepal_length',data=df,jitter=True,edgecolor='grey',size=7,palette='hot',orient='v')

# %%
# violinplot depicting different parameter

# %%
plt.figure(figsize=(28,15))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='petal_length',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='petal_length',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='petal_width',data=df)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='sepal_length',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='sepal_width',data=df)
plt.show()

# %%
# Paired Plot

# %%
sns.pairplot(df,hue='species')
plt.show()

# %%
sns.pairplot(data=df,kind='scatter')
pass

# %%
# Distribution plot

# %%
df.hist(edgecolor="brown",linewidth=1)
fig=plt.gcf()
fig.set_size_inches(15,10)

# %%
# Violin plot

# %%
x=(df["sepal_length"])
a=(df["sepal_width"])
plt.figure(figsize=(5,5))
data=list([df["sepal_length"],df["sepal_width"]])
plt.title("Violinplot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.violinplot(data)
plt.grid(True)
plt.show()

# %%
# LM plot

# %%
fig=sns.lmplot(x="petal_length",y="petal_width",data=df)

# %%
# FacetGrid plot

# %%
sns.FacetGrid(df,hue='species',size=7)\
.map(sns.kdeplot,"petal_length")\
.add_legend()
plt.ioff()
# Out:
# E:\anaconda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Heat map

# %%
sns.heatmap(df.corr(),color='magenta',annot=True)
# Out:
# <AxesSubplot:>
