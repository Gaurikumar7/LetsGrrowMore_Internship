# %% [markdown]
# # Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# ## Author-Gaurikumar Shinde
# ### Data Science Intern @LGM
# ### Task - 04
# ### Task - Prediction using Decision Tree Algorithm

# %% [markdown]
# # importing libraries

# %%
# Importing neccessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



import warnings
warnings.filterwarnings('ignore')

# %%
#Reading dataset

# %%
df=pd.read_csv("C:/Users/Rushikesh/Desktop/globalterrorismdb_0718dist.csv")

# %%
#Reading first 5 columns of dataset

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
#To get number of rows and columns in dataset

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# Visualising all columns in the dataset

# %%
df.columns.tolist()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
#  'weaptype1',
#  'weaptype1_txt',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weaptype4',
#  'weaptype4_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weapdetail',
#  'nkill',
#  'nkillus',
#  'nkillter',
#  'nwound',
#  'nwoundus',
#  'nwoundte',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'ishostkid',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'ndays',
#  'divert',
#  'kidhijcountry',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransompaid',
#  'ransompaidus',
#  'ransomnote',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'nreleased',
#  'addnotes',
#  'scite1',
#  'scite2',
#  'scite3',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'INT_MISC',
#  'INT_ANY',
#  'related']

# %%
# Checking if there are any null values

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# # Rename the columns

# %%
# Renaming the wanted columns

# %%
df.rename(columns=({'iyear':'year','imonth':'month','iday':'day','approxdate':'date','country':'country','country_txt':'country_names','region':'region','region_txt':'region_names','provstate':'state','city':'city','latitude':'latitude','longitude':'longitude','summary':'summary','success':'success','suicide':'suicide','attacktype1':'attack_type','attacktype1_txt':'attacktype_name','targtype1':'target_type','targtype1_txt':'targettype_name','gname':'group','individual':'individual'}),inplace=True)
df.head()
# Out:
#         eventid  year  month  day date  extended resolution  country  \
# 0  197000000001  1970      7    2  NaN         0        NaN       58
# 1  197000000002  1970      0    0  NaN         0        NaN      130
# 2  197001000001  1970      1    0  NaN         0        NaN      160
# 3  197001000002  1970      1    0  NaN         0        NaN       78
# 4  197001000003  1970      1    0  NaN         0        NaN      101
#
#         country_names  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# # Data Preprocessing

# %%
# Selecting the columns which are necessary for EDA

# %%
df1=df[['year','month','day','country','country_names','region','region_names','state','city','success','suicide','attack_type','attacktype_name','nkill','nwound','target_type','targettype_name','group','individual']]

# %%
#Reading first five rows of new dataset

# %%
df1.head()
# Out:
#    year  month  day  country       country_names  region  \
# 0  1970      7    2       58  Dominican Republic       2
# 1  1970      0    0      130              Mexico       1
# 2  1970      1    0      160         Philippines       5
# 3  1970      1    0       78              Greece       8
# 4  1970      1    0      101               Japan       4
#
#                   region_names    state           city  success  suicide  \
# 0  Central America & Caribbean      NaN  Santo Domingo        1        0
# 1                North America  Federal    Mexico city        1        0
# 2               Southeast Asia   Tarlac        Unknown        1        0
# 3               Western Europe   Attica         Athens        1        0
# 4                    East Asia  Fukouka        Fukouka        1        0
#
#    attack_type                 attacktype_name  nkill  nwound  target_type  \
# 0            1                   Assassination    1.0     0.0           14
# 1            6     Hostage Taking (Kidnapping)    0.0     0.0            7
# 2            1                   Assassination    1.0     0.0           10
# 3            3               Bombing/Explosion    NaN     NaN            7
# 4            7  Facility/Infrastructure Attack    NaN     NaN            7
#
#                targettype_name                               group  individual
# 0  Private Citizens & Property                              MANO-D           0
# 1      Government (Diplomatic)  23rd of September Communist League           0
# 2          Journalists & Media                             Unknown           0
# 3      Government (Diplomatic)                             Unknown           0
# 4      Government (Diplomatic)                             Unknown           0

# %%
#Rows and columns of new dataset

# %%
df1.shape
# Out:
# (181691, 19)

# %%
#Checking for null values in new data set

# %%
df1.isnull().sum()
# Out:
# year                   0
# month                  0
# day                    0
# country                0
# country_names          0
# region                 0
# region_names           0
# state                421
# city                 434
# success                0
# suicide                0
# attack_type            0
# attacktype_name        0
# nkill              10313
# nwound             16311
# target_type            0
# targettype_name        0
# group                  0
# individual             0
# dtype: int64

# %% [markdown]
# ## Filling null values of state and city columns by using bfill function

# %%
#Replacing null values with zero

# %%
df1.fillna(0,inplace=True)

# %%
#Checking all the unique values in state column

# %%
df1['state'].unique().tolist()
# Out:
# [0,
#  'Federal',
#  'Tarlac',
#  'Attica',
#  'Fukouka',
#  'Illinois',
#  'Montevideo',
#  'California',
#  'Wisconsin',
#  'Colorado',
#  'Lazio',
#  'Michigan',
#  'Puerto Rico',
#  'Berlin',
#  'Unknown',
#  'New York',
#  'Washington',
#  'New Jersey',
#  'Guatemala',
#  'Metropolitan Manila',
#  'Caracas',
#  'Nebraska',
#  'Mississippi',
#  'Ohio',
#  'Florida',
#  'Oregon',
#  'Massachusetts',
#  'Bavaria',
#  'Maryland',
#  'Louisiana',
#  'Connecticut',
#  'Hesse',
#  'Zurich',
#  'Arizona',
#  'Khalil',
#  'Metropolitian Manila',
#  'Alabama',
#  'New Mexico',
#  'Sao Paulo',
#  'Alexandria',
#  'Montana',
#  'District of Columbia',
#  'Pampanga',
#  'National',
#  'Corrientes',
#  'Buenos Aires',
#  'Beirut',
#  'Georgia',
#  'Texas',
#  'Dublin',
#  'Rio Grande do Sul',
#  'Kansas',
#  'Missouri',
#  'Amman',
#  'Istanbul',
#  'Pennsylvania',
#  'Minnesota',
#  'Iowa',
#  'Indiana',
#  'Asuncion',
#  'North Carolina',
#  'Oklahoma',
#  'Idaho',
#  'Geneva',
#  'Utah',
#  'Capiz',
#  'Lara',
#  'Tehran',
#  'Rio de Janeiro',
#  'Northern Ireland',
#  'Caldas',
#  'Managua',
#  'Pernambuco',
#  'Navarre',
#  'North Holland',
#  'Brussels',
#  'Tucuman',
#  'Santa Fe',
#  'Ankara',
#  'Tennessee',
#  'Cordoba',
#  'England',
#  'Izmir',
#  'Quebec',
#  'West Virginia',
#  'Baden-Wurttemberg',
#  'Victoria',
#  'Sindh',
#  'Gipuzcoa',
#  'Burgos',
#  'Malatya',
#  'Amhara',
#  'Gilan',
#  'Vastra Gotaland',
#  'San Jose',
#  'Hawaii',
#  'South Holland',
#  'Santa Cruz de Tenerife',
#  'Lombardy',
#  'Esfahan',
#  'Madrid',
#  'Barcelona',
#  'Stockholm',
#  'La Paz',
#  'Nevada',
#  'Ionian Islands',
#  'Khuzestan',
#  'Valencia',
#  'Adan',
#  'Biscay',
#  'Rhode Island',
#  'Lerida',
#  'Vermont',
#  'Phnom Penh',
#  'Jerusalem',
#  'Opole',
#  'Penghu',
#  'New South Wales',
#  'Cairo',
#  'Fars',
#  'Panama',
#  'Gaza Strip',
#  'Vienna',
#  'North Brabant',
#  'Hamburg',
#  'New Hampshire',
#  'Delhi',
#  'Ordu',
#  'Isabela',
#  'Ontario',
#  'Paris',
#  'Central',
#  'Aragua',
#  'Pleiku',
#  'Bogota',
#  'Friuli-Venezia Giulia',
#  'Queensland',
#  'Ile-de-France',
#  'Cavan',
#  'Kinshasa',
#  'Brazzaville',
#  'Lisbon',
#  'North Rhine-Westphalia',
#  'Algiers',
#  'Virginia',
#  'Zaragoza',
#  'San Salvador',
#  'Antioquia',
#  'Bangkok',
#  'Donegal',
#  'Santiago',
#  'Rhineland-Palatinate',
#  'Tuscany',
#  'Ouest',
#  'Eritrea',
#  'East Azerbaijan',
#  'South Dakota',
#  'Khartoum',
#  'Grand Casablanca',
#  'Nicosia',
#  'Liguria',
#  'South',
#  'An Nabatiyah',
#  'Kanagawa',
#  'Kabul',
#  'Jalisco',
#  'Trujillo',
#  'Crete',
#  'Risaralda',
#  'Lima',
#  'Chaco',
#  'Santiago Metropolitan',
#  'Francisco Morazan',
#  'Essonne',
#  'Serbia',
#  'Schleswig-Holstein',
#  'Guayas',
#  'Canterbury',
#  'Tokyo',
#  'Emilia-Romagna',
#  'Lusaka',
#  'Lower Saxony',
#  'Hauts-de-Seine',
#  'Kuala Lumpur',
#  'Zulia',
#  'Doubs',
#  'Bouches-du-Rhone',
#  'Piedmont',
#  'Cochabamba',
#  'Mendoza',
#  'Saone-et-Loire',
#  'Seine-Saint-Denis',
#  'Singapore',
#  'Santa Ana',
#  'South-East',
#  'Asimah',
#  'Finistere',
#  'Haute-Garonne',
#  'Oaxaca',
#  'Monaghan',
#  'Guerrero',
#  'Corsica',
#  'Maekel',
#  'Northern',
#  'Zambales',
#  'Tibesti',
#  'Pattani',
#  'Amanat Al Asimah',
#  'Yucatan',
#  'Wallonia',
#  'Flanders',
#  'Bern',
#  'Macedonia',
#  'Hautes-Pyrenees',
#  'Hyogo',
#  'Gard',
#  'Kingston Parish',
#  'Aleppo',
#  'Salta',
#  'Arequipa',
#  'Campania',
#  'Pichincha',
#  'Morelos',
#  'Dubai',
#  'Lugo',
#  'Bremen',
#  'North-West Frontier Province',
#  'Tel Aviv',
#  'Gauteng',
#  'Punjab',
#  'Vaud',
#  'Razavi Khorasan',
#  'Bihar',
#  'State of Mexico',
#  'Nairobi',
#  'Cadiz',
#  'Finisere',
#  'Cauca',
#  'Limassol',
#  'Meta',
#  'Nineveh',
#  'Rhone',
#  'Galicia',
#  'Banaadir',
#  'Boyaca',
#  'Guipuzcoa',
#  'Valladolid',
#  'Coast',
#  'Mount Lebanon',
#  'Haut-Rhin',
#  'Pyrenees-Atlantiques',
#  'Alpes-Maritimes',
#  'Aichi',
#  'Seine-Maritime',
#  'Seville',
#  'Louth',
#  'Cork',
#  'Pontevedra',
#  'Kildare',
#  'Okinawa',
#  'Zamboanga del Sur',
#  'Nord',
#  'Alava',
#  'Oshana',
#  'Casanare',
#  'Ille-et-Vilaine',
#  'Scotland',
#  'Salamanca',
#  'Maine',
#  'Formosa',
#  'Chiquimula',
#  'Basilan',
#  'Drenthe',
#  'Calabria',
#  'Anzoategui',
#  'Bimini',
#  'Lagos',
#  'Otjozondjupa',
#  'Bas-Rhin',
#  'Ifugao',
#  'Kentucky',
#  'Porto',
#  'Atlantico',
#  'Misamis Oriental',
#  'Veneto',
#  'Apulia',
#  'Sardinia',
#  'Khomas',
#  'Trentino-South Tyrol',
#  'West Bank',
#  'Tigray',
#  'Valle del Cauca',
#  'Charente',
#  'Davao del Sur',
#  'Santander',
#  'Las Palmas',
#  'Sinaloa',
#  'Sonsonate',
#  'Puy-de-Dome',
#  'Saint Michael',
#  'Umbria',
#  'A Coruna',
#  'Isere',
#  'Cantabria',
#  'Girona',
#  'San Miguel',
#  'Herault',
#  'Port of Spain',
#  'Corse-du-Sud',
#  'Sicily',
#  'Laoighis',
#  'Addis Ababa',
#  'Usulutan',
#  'Christ Church',
#  'Islamabad Capital Territory',
#  'Marche',
#  'Taipei',
#  'Kirklareli',
#  'Balikesir',
#  'Gironde',
#  'Rangoon',
#  'Transvaal',
#  'Chihuahua',
#  'Baghdad',
#  'Basel-Stadt',
#  'Chittagong',
#  'Cabinda',
#  'Caqueta',
#  'Konya',
#  'Central Macedonia',
#  'Leon',
#  'Adana',
#  'Osmaniye',
#  'Diyarbakir',
#  'Zinguldak',
#  'Gaziantep',
#  'Bursa',
#  'Azores',
#  'Antalya',
#  'Aydin',
#  'Manisa',
#  'Somali',
#  'Katanga',
#  'Alajuela',
#  'Tiris Zemmour',
#  'Mersin',
#  'Erzincan',
#  'Songkhla',
#  'Ourense',
#  'Toledo',
#  'Kocaeli',
#  'Seine-et-Marne',
#  'Slovenia',
#  'Tarragona',
#  'Arica and Parinacota',
#  'Sivas',
#  "Cotes-d'Armor",
#  'San Luis Potosi',
#  'KwaZulu-Natal',
#  'Samsun',
#  'Southern',
#  'Hatay',
#  'Carinthia',
#  'Malaga',
#  'Sanliurfa',
#  'Tokat',
#  'Kahramanmaras',
#  'Erzurum',
#  'Bolivar',
#  'Evora',
#  'Santarem',
#  'Setubal',
#  'Beja',
#  'Tolima',
#  'Utrecht',
#  'Yala',
#  'Maharashtra',
#  'Haute-Corse',
#  'Nueva Segovia',
#  'Balearic Islands',
#  'Rio San Juan',
#  'Abruzzo',
#  'Masaya',
#  'Cundinamarca',
#  'Mayenne',
#  'Abu Dhabi',
#  'Segovia',
#  'Dikhil',
#  'North Sumatra',
#  'Huila',
#  'Moselle',
#  'Jura',
#  'Putumayo',
#  'Quindio',
#  'Murcia',
#  'Yonne',
#  'Aude',
#  'Kyoto',
#  'Mashonaland South',
#  'Russia',
#  'Basilicata',
#  'Maguindanao',
#  'Chinandega',
#  'Ibaraki',
#  'Matagalpa',
#  'Granada',
#  'Palencia',
#  'Esteli',
#  'Alaska',
#  'Carabobo',
#  'Sucre',
#  'Chiba',
#  'Carazo',
#  'Cabanas',
#  'San Vicente',
#  'Asturias',
#  'North West',
#  'Eastern Cape',
#  'Haifa',
#  'Cuscatlan',
#  'Chalatenango',
#  'Parana',
#  'Tamaulipas',
#  'San Pedro de Macoris',
#  'Papua',
#  'Saitama',
#  'Manicaland',
#  'Cesar',
#  'Qom',
#  'Norte de Santander',
#  'La Guajira',
#  'Tribal Trust Lands',
#  'Escuintla',
#  'Doha',
#  'Magdalena',
#  'Matabeleland South',
#  'Limerick',
#  'North',
#  'Osaka',
#  'Midland',
#  'Yvelines',
#  'Mashonaland West',
#  'Huehuetenango',
#  'Aosta',
#  'Sulu',
#  'Ayacucho',
#  'Soria',
#  'Sa Kaeo',
#  'Mashonland',
#  'Lanao del Sur',
#  'Quetzaltenango',
#  'North Cotabato',
#  'Minas Gerais',
#  'Salisbury',
#  'Davao Oriental',
#  'Kalinga',
#  'Veracruz',
#  'Davao del Norte',
#  'North Sinai',
#  'Surat Thani',
#  'Totonicapan',
#  'Daraa',
#  'Basque Country',
#  'Monagas',
#  'La Libertad',
#  'Kars',
#  'Omusati',
#  'Bingol',
#  'San Marcos',
#  'Chontales',
#  'Huambo',
#  'Nueva Ecija',
#  'Rivas',
#  'Ahuachapan',
#  'Antofagasta',
#  'Barima-Waini',
#  'Miranda',
#  'Maputo',
#  'Andalusia',
#  'Delaware',
#  'Sultan Kudarat',
#  'Mardin',
#  'Guelmim-Es Semara',
#  'Chubut',
#  'Sofala',
#  'Narino',
#  'Ica',
#  'Erongo',
#  'Gwelo',
#  'Shan',
#  'Australian Capital Territory',
#  'Canary Islands',
#  'Madriz',
#  'Tunis',
#  'Umtali',
#  'Assam',
#  'Manipur',
#  'Capital',
#  'Kerman',
#  'Catalonia',
#  'Quiche',
#  'Bulawayo',
#  'Meknes-Tafilalet',
#  'Oran',
#  'Choco',
#  'Eastern',
#  'Chiriqui',
#  'Puebla',
#  'Ohangwena',
#  'Melilla',
#  'Qazvin',
#  'Trang',
#  'Aargau',
#  'Valparaiso',
#  'Oslo',
#  'West Azerbaijan',
#  'Ceuta',
#  'Mon',
#  'Lanao del Norte',
#  'Oshikoto',
#  'Chin',
#  'Tawi Tawi',
#  'Dhaka',
#  'Western Australia',
#  'Var',
#  'Inhambane',
#  'Krakow',
#  'Matabeleland',
#  'Manica',
#  'Krabi',
#  'Kanchanaburi',
#  'Chiang Mai',
#  'Suchitepequez',
#  'Zamboanga del Norte',
#  'Maseru',
#  'Cortes',
#  'Jinotega',
#  'Western Cape',
#  'Castile and Leon',
#  'South Caribbean Coast Autonomous Region',
#  'Zacapa',
#  'Luanda',
#  'Zelaya',
#  'Udon Thani',
#  'Hamah',
#  'Kermanshah',
#  'Barinas',
#  'Northern Samar',
#  'Dar es Salaam',
#  'Mizoram',
#  'Sistan and Balochistan',
#  'Basra',
#  'Mashonaland East',
#  'Estuaire',
#  'Bio Bio',
#  'Aragon',
#  'Rif Dimashq',
#  'Damascus',
#  'Val-de-Marne',
#  'Burdur',
#  'Ilam',
#  'Golan Heights',
#  'Demerara-Mahaica',
#  'Kordestan',
#  'Perak',
#  'Denizli',
#  'Waterford',
#  'Homs',
#  'Andhra Pradesh',
#  'Coquimbo',
#  'Zanjan',
#  'Latakia',
#  'Tripoli',
#  'Jharkhand',
#  'Sligo',
#  'Ghazni',
#  'Tunceli',
#  'Tamil Nadu',
#  'Herat',
#  'Choluteca',
#  'Bitlis',
#  'Espirito Santo',
#  'Coimbra',
#  'La Union',
#  'Santa Cruz',
#  'Murqub',
#  'Adiyaman',
#  'Apure',
#  'Solola',
#  'Peten',
#  'Solothurn',
#  'Mpumalanga',
#  'Makkah',
#  'Kayseri',
#  'Alta Verapaz',
#  'Uttar Pradesh',
#  'Oruro',
#  'Kaduna',
#  'Espaillat',
#  'Gafsa',
#  'Orange Free State',
#  'Nong Khai',
#  'Hong Kong',
#  'Natal',
#  'Midlands',
#  'El Progreso',
#  'Caaguazu',
#  'Misamis Occidental',
#  'Baja Verapaz',
#  'Bophutatswana',
#  'Moraz�n',
#  'Morazan',
#  'Dakar',
#  'Nakhon Si Thammarat',
#  'At Tamim',
#  'Kamphaeng Phet',
#  'West Bengal',
#  'Arauca',
#  'Lorestan',
#  'Golestan',
#  'Cuscatl�n',
#  'Izabal',
#  'Beqaa',
#  'Usak',
#  'Narathiwat',
#  'Elazig',
#  'Chaiyaphum',
#  'Jahra',
#  'Jutiapa',
#  'Trabzon',
#  'Algarve',
#  'Conakry',
#  'Chimaltenango',
#  'Boaco',
#  'Amasya',
#  'Al Hasakah',
#  'Nevsehir',
#  'Tarija',
#  'Saint George',
#  'Potosi',
#  'Offaly',
#  'Shefa',
#  'Belize',
#  'Siirt',
#  'Ismailia',
#  'Wales',
#  'La Rioja',
#  'Benghazi',
#  'Hamadan',
#  'Sacatepequez',
#  'El Paraiso',
#  'Ancash',
#  'Junin',
#  'Retahuleu',
#  'Cusco',
#  'Benguet',
#  'Huancavelica',
#  'Santa Rosa',
#  'Pointe-a-Pitre',
#  'Samar',
#  'Cavite',
#  'Cabrican',
#  'Atacama',
#  'Lambayeque',
#  'Wexford',
#  'Pasco',
#  'Guainia',
#  'Saint Patrick',
#  'Central Jutland',
#  'Callao',
#  'Santa Barbara',
#  'Puno',
#  'Loreto',
#  'South Cotabato',
#  'Valle',
#  'Sulaymaniyah',
#  'North Caribbean Coast Autonomous Region',
#  'Usulut�n',
#  'Idlib',
#  'Masvingo',
#  'Jakarta',
#  'New Providence',
#  'Cajamarca',
#  'Nagaland',
#  'El Peten',
#  'Moquegua',
#  'Limpopo',
#  'Vatican City',
#  'Mato Grosso do Sul',
#  'Kirkuk',
#  'Eastern Samar',
#  'Guna Yala',
#  'Bangui',
#  'Tarapaca',
#  'Kohgiluyeh and Buyer Ahmad',
#  'Mazandaran',
#  'Warsaw',
#  'Brandenburg',
#  'Sucumbios',
#  'Yazd',
#  'Tacna',
#  'Gujarat',
#  'Los Rios',
#  'Chiang Rai',
#  'Asyut',
#  'Chandigarh',
#  'La Uni�n',
#  'Amazonas',
#  'Castelo Branco',
#  'Loire-Atlantique',
#  'Lot-et-Garonne',
#  'Lempira',
#  'Mont Buxton',
#  'Apurimac',
#  'Western',
#  'Sirnak',
#  'Huanuco',
#  'Aquitaine',
#  'Atlantico Norte',
#  'Rhone-Alpes',
#  'Cartago',
#  "Provence-Alpes-Cote d'Azur",
#  'Abra',
#  'Chiapas',
#  'Busan',
#  'Khulna',
#  'Retalhuleu',
#  'Limousin',
#  'Quneitra',
#  'Caba�as',
#  'Chimborazo',
#  'Languedoc-Roussillon',
#  'Midi-Pyrenees',
#  'Juitapa',
#  'Matabeleland North',
#  'Salzburg',
#  'Rajasthan',
#  'Burgas',
#  'Paramaribo',
#  'Cuanza Sul',
#  'Manzini',
#  'Zambezia',
#  'Bukidnon',
#  'Piura',
#  'Neuqu�n',
#  'Tete',
#  'Cuscaltan',
#  'North Dakota',
#  'Benguela',
#  'Tanintharyi',
#  'Gaza',
#  'Tachira',
#  'Luxembourg',
#  'Guaviare',
#  'Berea',
#  'Quthing',
#  'Leribe',
#  'Chhattisgarh',
#  'Yoro',
#  'Eastern Macedonia and Thrace',
#  'Faro',
#  'Capital Region',
#  'Chuquisaca',
#  'Saint Laurent Du Maroni',
#  'Cayenne',
#  'Fort-de-France',
#  "O'Higgins",
#  'Butha-Buthe',
#  'Malanje',
#  'Maule',
#  'East Falkland',
#  'Bahia',
#  'Ciskei',
#  'Lunda Norte',
#  'Olancho',
#  'San Martin',
#  'Atlantida',
#  'Catamarca',
#  'Para',
#  'Daegu',
#  'Zarqa',
#  'Michoacan',
#  'Yamaguchi',
#  'Arkansas',
#  'Falcon',
#  'Atlantico Sur',
#  'Hormozgan',
#  'Basse-Terre',
#  'Al Wahdah',
#  'Pointe-�-Pitre',
#  'Leiria',
#  'Ahmadi',
#  'Leitrim',
#  'Tripura',
#  'West Kordofan',
#  'Haryana',
#  'Napo',
#  "N'Djamena",
#  'Los Lagos',
#  'Alsace',
#  'Wellington',
#  'Le Marin',
#  'Magallanes & Chilean Antarctica',
#  'Camarines Sur',
#  'Negros Occidental',
#  'Central Equatoria',
#  'Jammu and Kashmir',
#  'Federal District',
#  'Himachal Pradesh',
#  'Jabal al Akhdar',
#  'Colon',
#  'Laayoune-Boujdour-Sakia El Hamra',
#  'Magdeburg',
#  'Kavango',
#  'Kosovo',
#  'Araucania',
#  'Centre',
#  'Woqooyi Galbeed',
#  'Federally Administered Tribal Areas',
#  'Karnataka',
#  'Hakkari',
#  'Varna',
#  'Larnaca',
#  'Cuanza Norte',
#  'South Eastern',
#  'Surigao del Sur',
#  'South Province',
#  'North Province',
#  'Bengo',
#  'Davao',
#  'Bucharest',
#  'Hhohho',
#  'Cebu',
#  'Uige',
#  'Aguasan Del Sur',
#  'Saxony-Anhalt',
#  'Chiaha',
#  'East Java',
#  'Riyadh',
#  'Valais',
#  'Center',
#  'San Juan',
#  'Ilocos Norte',
#  'Esmeraldas',
#  'Manabi',
#  'North Central',
#  'Rabat-Sale-Zemmour-Zaer',
#  'Tahoua',
#  'Agusan del Norte',
#  'Brittany',
#  'Apayao',
#  'Guanacaste',
#  'Far-Western',
#  'North Western',
#  'Cagayan',
#  'Bataan',
#  'Vichada',
#  'Saarland',
#  'Ucayali',
#  'Caprivi',
#  'Iloilo',
#  'Zamboanga Sibugay',
#  'Kalinga Apayao',
#  'Entre Rios',
#  'Maritime',
#  'Bulacan',
#  'Nueva Vizcaya',
#  'Groningen',
#  'Leyte',
#  'Norhtern',
#  'Uva',
#  'Sabah',
#  'Oriental Mindoro',
#  'Camiguin',
#  'Negros Oriental',
#  'Tyrol',
#  'Yaracuy',
#  'Jujuy',
#  'North-Western',
#  'San Luis',
#  'British Columbia',
#  'Bie',
#  'Eastern Equatoria',
#  'Balochistan',
#  'Uusimaa',
#  'Azuay',
#  'Sabaragamuwa',
#  'Marowijne',
#  'KwaNdebele',
#  'Northern Cape',
#  'Maldonado',
#  'Extremadura',
#  'Seoul',
#  'Acre',
#  'Castile-La Mancha',
#  'Western Region',
#  'Batman',
#  'Guarico',
#  'Upper Nile',
#  'Ocotepeque',
#  'Djibouti',
#  'Commewyne',
#  'Jalapa',
#  'Quezon',
#  'Brokopondo',
#  'Harare',
#  'Merida',
#  'Dihok',
#  'Ilocos Sur',
#  'Tumbes',
#  'Agri',
#  'Khyber Pakhtunkhwa',
#  'Guimaras',
#  'Cuando Cubango',
#  'Greater Accra',
#  'Karas',
#  'Batangas',
#  'Albay',
#  'Rewa',
#  'Sousse',
#  'Monastir',
#  'Comayagua',
#  'Misiones',
#  'Uttaranchal',
#  'Madhya Pradesh',
#  'Saladin',
#  'Barisal',
#  'Gumushane',
#  'Monsenor Nouel',
#  'Orissa',
#  'Pangasinan',
#  'Zamora-Chinchipe',
#  'Transkei',
#  'Kachin',
#  'Cabo Delgado',
#  'Sennar',
#  'Biliran',
#  'Occidental Mindoro',
#  'Southern Leyte',
#  'North Eastern',
#  'Rajshahi',
#  'Corum',
#  'Eastern Province',
#  'Mountain Province',
#  'Chonburi',
#  'Faryab',
#  'Kayin',
#  'Vaupes',
#  'Limburg',
#  'Sylhet',
#  'Loyalty Islands Province',
#  'Sorsogon',
#  'Sakarya',
#  'Paraiba',
#  'Kilis',
#  'Gwangju',
#  'Western Greece',
#  'Togdheer',
#  'Van',
#  'Laguna',
#  'Nangarhar',
#  'Rangpur',
#  'Sohag',
#  'Orientale',
#  'Franche-Comte',
#  'Bohol',
#  'Male',
#  'Plaines Wilhems',
#  'Tabasco',
#  'Kayah',
#  'Nampula',
#  'Overijssel',
#  'South Australia',
#  'Sipaliwini',
#  'Ziguinchor',
#  'Aysen',
#  'East Timor',
#  'Ishikawa',
#  'Minya',
#  'Barahona',
#  'Severocesky',
#  'Yangon',
#  'Budapest',
#  'Mandalay',
#  'Vientiane',
#  'La Pampa',
#  'Savanne',
#  'Masbate',
#  'Camarines Norte',
#  'Prague',
#  'Nassa',
#  'Battambang',
#  'Aklan',
#  'Croatia',
#  'Faiyum',
#  'Jonglei',
#  'Zhejiang',
#  'South Aegean',
#  'Jihomoravsky',
#  'Pays-de-la-Loire',
#  ...]

# %%
#All null values got replaced after filling it by 0

# %%
df1.isnull().sum()
# Out:
# year               0
# month              0
# day                0
# country            0
# country_names      0
# region             0
# region_names       0
# state              0
# city               0
# success            0
# suicide            0
# attack_type        0
# attacktype_name    0
# nkill              0
# nwound             0
# target_type        0
# targettype_name    0
# group              0
# individual         0
# dtype: int64

# %%
#Data set is cleaned

# %%
# Checking what is present in new dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   year             181691 non-null  int64
#  1   month            181691 non-null  int64
#  2   day              181691 non-null  int64
#  3   country          181691 non-null  int64
#  4   country_names    181691 non-null  object
#  5   region           181691 non-null  int64
#  6   region_names     181691 non-null  object
#  7   state            181691 non-null  object
#  8   city             181691 non-null  object
#  9   success          181691 non-null  int64
#  10  suicide          181691 non-null  int64
#  11  attack_type      181691 non-null  int64
#  12  attacktype_name  181691 non-null  object
#  13  nkill            181691 non-null  float64
#  14  nwound           181691 non-null  float64
#  15  target_type      181691 non-null  int64
#  16  targettype_name  181691 non-null  object
#  17  group            181691 non-null  object
#  18  individual       181691 non-null  int64
# dtypes: float64(2), int64(10), object(7)
# memory usage: 26.3+ MB

# %%
# To check number of unique values in dataset

# %%
df1.nunique()
# Out:
# year                  47
# month                 13
# day                   32
# country              205
# country_names        205
# region                12
# region_names          12
# state               2855
# city               36675
# success                2
# suicide                2
# attack_type            9
# attacktype_name        9
# nkill                205
# nwound               238
# target_type           22
# targettype_name       22
# group               3537
# individual             2
# dtype: int64

# %%
#Statistical analysis of dataset

# %%
df1.describe()
# Out:
#                 year          month            day        country  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644     131.968501
# std        13.259430       3.388303       8.814045     112.414535
# min      1970.000000       0.000000       0.000000       4.000000
# 25%      1991.000000       4.000000       8.000000      78.000000
# 50%      2009.000000       6.000000      15.000000      98.000000
# 75%      2014.000000       9.000000      23.000000     160.000000
# max      2017.000000      12.000000      31.000000    1004.000000
#
#               region        success        suicide    attack_type  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean        7.160938       0.889598       0.036507       3.247547
# std         2.933408       0.313391       0.187549       1.915772
# min         1.000000       0.000000       0.000000       1.000000
# 25%         5.000000       1.000000       0.000000       2.000000
# 50%         6.000000       1.000000       0.000000       3.000000
# 75%        10.000000       1.000000       0.000000       3.000000
# max        12.000000       1.000000       1.000000       9.000000
#
#                nkill         nwound    target_type     individual
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean        2.266860       2.883296       8.439719       0.002950
# std        11.227057      34.309747       6.653838       0.054234
# min         0.000000       0.000000       1.000000       0.000000
# 25%         0.000000       0.000000       3.000000       0.000000
# 50%         0.000000       0.000000       4.000000       0.000000
# 75%         2.000000       2.000000      14.000000       0.000000
# max      1570.000000    8191.000000      22.000000       1.000000

# %%
#Correlation of dataset

# %%
correlation=df1.corr()
correlation
# Out:
#                  year     month       day   country    region   success  \
# year         1.000000  0.000139  0.018254 -0.135023  0.401384 -0.082963
# month        0.000139  1.000000  0.005497 -0.006305 -0.002999 -0.002845
# day          0.018254  0.005497  1.000000  0.003468  0.009710 -0.011802
# country     -0.135023 -0.006305  0.003468  1.000000  0.148597 -0.037827
# region       0.401384 -0.002999  0.009710  0.148597  1.000000 -0.030909
# success     -0.082963 -0.002845 -0.011802 -0.037827 -0.030909  1.000000
# suicide      0.137736  0.003071  0.003593 -0.050360  0.112672 -0.031155
# attack_type  0.074153  0.006705 -0.005333 -0.021384  0.007642  0.048408
# nkill        0.021252  0.004031 -0.003225 -0.014383  0.043113  0.049619
# nwound       0.017484  0.003178 -0.001082 -0.006351  0.019211  0.023346
# target_type  0.079082 -0.000948 -0.000052 -0.019703  0.041396 -0.059637
# individual   0.017944 -0.001661 -0.003788  0.027918 -0.059963 -0.013868
#
#               suicide  attack_type     nkill    nwound  target_type  \
# year         0.137736     0.074153  0.021252  0.017484     0.079082
# month        0.003071     0.006705  0.004031  0.003178    -0.000948
# day          0.003593    -0.005333 -0.003225 -0.001082    -0.000052
# country     -0.050360    -0.021384 -0.014383 -0.006351    -0.019703
# region       0.112672     0.007642  0.043113  0.019211     0.041396
# success     -0.031155     0.048408  0.049619  0.023346    -0.059637
# suicide      1.000000    -0.029962  0.136385  0.096101    -0.023440
# attack_type -0.029962     1.000000 -0.003448 -0.001424     0.014513
# nkill        0.136385    -0.003448  1.000000  0.443326     0.008466
# nwound       0.096101    -0.001424  0.443326  1.000000     0.010709
# target_type -0.023440     0.014513  0.008466  0.010709     1.000000
# individual   0.000775     0.016438 -0.001275  0.008432     0.005267
#
#              individual
# year           0.017944
# month         -0.001661
# day           -0.003788
# country        0.027918
# region        -0.059963
# success       -0.013868
# suicide        0.000775
# attack_type    0.016438
# nkill         -0.001275
# nwound         0.008432
# target_type    0.005267
# individual     1.000000

# %%
df1.count()
# Out:
# year               181691
# month              181691
# day                181691
# country            181691
# country_names      181691
# region             181691
# region_names       181691
# state              181691
# city               181691
# success            181691
# suicide            181691
# attack_type        181691
# attacktype_name    181691
# nkill              181691
# nwound             181691
# target_type        181691
# targettype_name    181691
# group              181691
# individual         181691
# dtype: int64

# %%
df1.loc[133458:133466]
# Out:
#         year  month  day  country country_names  region    region_names  \
# 133458  2014      6   14      214       Ukraine       9  Eastern Europe
# 133459  2014      6   14       92         India       6      South Asia
# 133460  2014      6   14        4   Afghanistan       6      South Asia
# 133461  2014      6   14        4   Afghanistan       6      South Asia
# 133462  2014      6   14        4   Afghanistan       6      South Asia
# 133463  2014      6   14        4   Afghanistan       6      South Asia
# 133464  2014      6   14        4   Afghanistan       6      South Asia
# 133465  2014      6   14        4   Afghanistan       6      South Asia
# 133466  2014      6   14        4   Afghanistan       6      South Asia
#
#             state       city  success  suicide  attack_type  \
# 133458    Donetsk  Avdiyivka        1        0            6
# 133459      Assam    Chirang        1        0            6
# 133460  Nangarhar    Unknown        1        0            7
# 133461  Nangarhar    Unknown        1        0            7
# 133462  Nangarhar    Unknown        1        0            7
# 133463  Nangarhar    Unknown        1        0            7
# 133464  Nangarhar    Unknown        1        0            7
# 133465  Nangarhar    Unknown        1        0            7
# 133466  Nangarhar    Unknown        1        0            7
#
#                        attacktype_name  nkill  nwound  target_type  \
# 133458     Hostage Taking (Kidnapping)    0.0     0.0            4
# 133459     Hostage Taking (Kidnapping)    0.0     0.0           14
# 133460  Facility/Infrastructure Attack    0.0     0.0            2
# 133461  Facility/Infrastructure Attack    0.0     0.0            2
# 133462  Facility/Infrastructure Attack    0.0     0.0            2
# 133463  Facility/Infrastructure Attack    0.0     0.0            2
# 133464  Facility/Infrastructure Attack    0.0     0.0            2
# 133465  Facility/Infrastructure Attack    0.0     0.0            2
# 133466  Facility/Infrastructure Attack    0.0     0.0            2
#
#                     targettype_name    group  individual
# 133458                     Military  Unknown           0
# 133459  Private Citizens & Property  Unknown           0
# 133460         Government (General)  Unknown           0
# 133461         Government (General)  Unknown           0
# 133462         Government (General)  Unknown           0
# 133463         Government (General)  Unknown           0
# 133464         Government (General)  Unknown           0
# 133465         Government (General)  Unknown           0
# 133466         Government (General)  Unknown           0

# %%
# finding rank

# %%
df1.rank()
# Out:
#             year     month       day   country    region   success  suicide  \
# 0          326.0   99612.5   10212.5   33157.5    8628.5  100875.5  87529.5
# 1          326.0      10.5     446.0   98807.5    1728.5  100875.5  87529.5
# 2          326.0    7488.5     446.0  134108.5   39823.0  100875.5  87529.5
# 3          326.0    7488.5     446.0   45800.0   99922.0  100875.5  87529.5
# 4          326.0    7488.5     446.0   91627.5   33179.5  100875.5  87529.5
# ...          ...       ...       ...       ...       ...       ...      ...
# 181686  176241.5  174943.5  180144.0  142816.5  172634.5  100875.5  87529.5
# 181687  176241.5  174943.5  180144.0  155608.0  138622.5  100875.5  87529.5
# 181688  176241.5  174943.5  180144.0  134108.5   39823.0  100875.5  87529.5
# 181689  176241.5  174943.5  180144.0   55200.5   68552.5   10030.0  87529.5
# 181690  176241.5  174943.5  180144.0  134108.5   39823.0   10030.0  87529.5
#
#         attack_type     nkill    nwound  target_type  individual
# 0            9656.5  116750.5   59793.5     130422.0     90578.0
# 1          157465.5   49231.5   59793.5      97835.0     90578.0
# 2            9656.5  116750.5   59793.5     105734.5     90578.0
# 3          106109.0   49231.5   59793.5      97835.0     90578.0
# 4          168222.5   49231.5   59793.5      97835.0     90578.0
# ...             ...       ...       ...          ...         ...
# 181686      40647.0  116750.5  140729.0      80450.5     90578.0
# 181687     106109.0  142112.0  165915.0      80450.5     90578.0
# 181688     168222.5   49231.5   59793.5     130422.0     90578.0
# 181689     106109.0   49231.5   59793.5      31311.0     90578.0
# 181690     106109.0   49231.5   59793.5     170853.5     90578.0
#
# [181691 rows x 12 columns]

# %%
# Check the median of each column

# %%
df1.median()
# Out:
# year           2009.0
# month             6.0
# day              15.0
# country          98.0
# region            6.0
# success           1.0
# suicide           0.0
# attack_type       3.0
# nkill             0.0
# nwound            0.0
# target_type       4.0
# individual        0.0
# dtype: float64

# %%
df1.head()
# Out:
#    year  month  day  country       country_names  region  \
# 0  1970      7    2       58  Dominican Republic       2
# 1  1970      0    0      130              Mexico       1
# 2  1970      1    0      160         Philippines       5
# 3  1970      1    0       78              Greece       8
# 4  1970      1    0      101               Japan       4
#
#                   region_names    state           city  success  suicide  \
# 0  Central America & Caribbean        0  Santo Domingo        1        0
# 1                North America  Federal    Mexico city        1        0
# 2               Southeast Asia   Tarlac        Unknown        1        0
# 3               Western Europe   Attica         Athens        1        0
# 4                    East Asia  Fukouka        Fukouka        1        0
#
#    attack_type                 attacktype_name  nkill  nwound  target_type  \
# 0            1                   Assassination    1.0     0.0           14
# 1            6     Hostage Taking (Kidnapping)    0.0     0.0            7
# 2            1                   Assassination    1.0     0.0           10
# 3            3               Bombing/Explosion    0.0     0.0            7
# 4            7  Facility/Infrastructure Attack    0.0     0.0            7
#
#                targettype_name                               group  individual
# 0  Private Citizens & Property                              MANO-D           0
# 1      Government (Diplomatic)  23rd of September Communist League           0
# 2          Journalists & Media                             Unknown           0
# 3      Government (Diplomatic)                             Unknown           0
# 4      Government (Diplomatic)                             Unknown           0

# %%
#Replacing 0 by using bfill method in every case

# %%
new_df=df1.replace(0,method='bfill')

# %%
new_df
# Out:
#         year  month  day  country       country_names  region  \
# 0       1970      7    2       58  Dominican Republic       2
# 1       1970      1    1      130              Mexico       1
# 2       1970      1    1      160         Philippines       5
# 3       1970      1    1       78              Greece       8
# 4       1970      1    1      101               Japan       4
# ...      ...    ...  ...      ...                 ...     ...
# 181686  2017     12   31      182             Somalia      11
# 181687  2017     12   31      200               Syria      10
# 181688  2017     12   31      160         Philippines       5
# 181689  2017     12   31       92               India       6
# 181690  2017     12   31      160         Philippines       5
#
#                        region_names            state           city  success  \
# 0       Central America & Caribbean          Federal  Santo Domingo        1
# 1                     North America          Federal    Mexico city        1
# 2                    Southeast Asia           Tarlac        Unknown        1
# 3                    Western Europe           Attica         Athens        1
# 4                         East Asia          Fukouka        Fukouka        1
# ...                             ...              ...            ...      ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow        1
# 181687   Middle East & North Africa         Lattakia         Jableh        1
# 181688               Southeast Asia      Maguindanao       Kubentog        1
# 181689                   South Asia          Manipur         Imphal        0
# 181690               Southeast Asia      Maguindanao  Cotabato City        0
#
#         suicide  attack_type                 attacktype_name  nkill  nwound  \
# 0             1            1                   Assassination    1.0     1.0
# 1             1            6     Hostage Taking (Kidnapping)    1.0     1.0
# 2             1            1                   Assassination    1.0     1.0
# 3             1            3               Bombing/Explosion    1.0     1.0
# 4             1            7  Facility/Infrastructure Attack    1.0     1.0
# ...         ...          ...                             ...    ...     ...
# 181686        0            2                   Armed Assault    1.0     2.0
# 181687        0            3               Bombing/Explosion    2.0     7.0
# 181688        0            7  Facility/Infrastructure Attack    0.0     0.0
# 181689        0            3               Bombing/Explosion    0.0     0.0
# 181690        0            3               Bombing/Explosion    0.0     0.0
#
#         target_type              targettype_name  \
# 0                14  Private Citizens & Property
# 1                 7      Government (Diplomatic)
# 2                10          Journalists & Media
# 3                 7      Government (Diplomatic)
# 4                 7      Government (Diplomatic)
# ...             ...                          ...
# 181686            4                     Military
# 181687            4                     Military
# 181688           14  Private Citizens & Property
# 181689            2         Government (General)
# 181690           20                      Unknown
#
#                                              group  individual
# 0                                           MANO-D           1
# 1               23rd of September Communist League           1
# 2                                          Unknown           1
# 3                                          Unknown           1
# 4                                          Unknown           1
# ...                                            ...         ...
# 181686                                  Al-Shabaab           0
# 181687                           Muslim extremists           0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)           0
# 181689                                     Unknown           0
# 181690                                     Unknown           0
#
# [181691 rows x 19 columns]

# %%
#Checking for the top rows of attack type column

# %%
new_df.sort_values(by='attack_type',ascending=False)[:30]
# Out:
#         year  month  day  country country_names  region  \
# 165889  2016      8   11        4   Afghanistan       6
# 150438  2015      7   10       37      Cameroon      11
# 150436  2015      7   10        4   Afghanistan       6
# 27394   1986      2   26      110       Lebanon      10
# 27404   1986      2   27       45      Colombia       3
# 174789  2017      5   15      209        Turkey      10
# 174790  2017      5   15      209        Turkey      10
# 27405   1986      2   27      159          Peru       3
# 27406   1986      2   27      159          Peru       3
# 27413   1986      3    1        8        Angola      11
# 58668   1995      3    3      101         Japan       4
# 27419   1986      3    3      159          Peru       3
# 174801  2017      5   15        4   Afghanistan       6
# 27422   1986      3    3      183  South Africa      11
# 174802  2017      5   15        4   Afghanistan       6
# 132632  2014      5   29      182       Somalia      11
# 150397  2015      7    9      228         Yemen      10
# 150396  2015      7    9      228         Yemen      10
# 150395  2015      7    9      228         Yemen      10
# 58672   1995      3    4      159          Peru       3
# 150390  2015      7    9        4   Afghanistan       6
# 27437   1986      3    6       92         India       6
# 150389  2015      7    9        4   Afghanistan       6
# 150388  2015      7    9        4   Afghanistan       6
# 111919  2012     10   27       95          Iraq      10
# 111918  2012     10   27       95          Iraq      10
# 11801   1980      9    8      205      Thailand       5
# 58678   1995      3    5      153      Pakistan       6
# 150371  2015      7    9       95          Iraq      10
# 150369  2015      7    9       95          Iraq      10
#
#                       region_names           state                       city  \
# 165889                  South Asia          Faryab  Khwaja Sabz Posh district
# 150438          Sub-Saharan Africa   Extreme-North                    Fotokol
# 150436                  South Asia           Kunar                    Gulsaik
# 27394   Middle East & North Africa           South                    Salhani
# 27404                South America       Antioquia                     Itagui
# 174789  Middle East & North Africa      Diyarbakir             Dicle district
# 174790  Middle East & North Africa          Sirnak                     Gormec
# 27405                South America        Apurimac          Aymaraes district
# 27406                South America        Apurimac                     Toraya
# 27413           Sub-Saharan Africa     Lunda Norte                    Andrada
# 58668                    East Asia           Tokyo                      Tokyo
# 27419                South America         Unknown                  Carclampa
# 174801                  South Asia         Badghis                     Langar
# 27422           Sub-Saharan Africa    Western Cape                  Gugulethu
# 174802                  South Asia          Faryab                    Maymana
# 132632          Sub-Saharan Africa  Lower Shebelle                      Leego
# 150397  Middle East & North Africa           Abyan                    Unknown
# 150396  Middle East & North Africa           Abyan                   Zinjibar
# 150395  Middle East & North Africa           Abyan                    Unknown
# 58672                South America    Huancavelica                     Ramaya
# 150390                  South Asia          Ghazni              Qaleh-ye Azad
# 27437                   South Asia          Punjab                 Kapurthala
# 150389                  South Asia          Ghazni                   Bakhtiar
# 150388                  South Asia          Ghazni                      Warah
# 111919  Middle East & North Africa          Diyala                 Muqdadiyah
# 111918  Middle East & North Africa          Diyala                 Muqdadiyah
# 11801               Southeast Asia        Songkhla                      Sadao
# 58678                   South Asia           Sindh                    Karachi
# 150371  Middle East & North Africa         Saladin                    Samarra
# 150369  Middle East & North Africa         Saladin             Tall Abu Jarad
#
#         success  suicide  attack_type attacktype_name  nkill  nwound  \
# 165889        1        1            9         Unknown    1.0    20.0
# 150438        1        1            9         Unknown    2.0     1.0
# 150436        1        1            9         Unknown    2.0     1.0
# 27394         1        1            9         Unknown    1.0     4.0
# 27404         1        1            9         Unknown    3.0     2.0
# 174789        1        1            9         Unknown    1.0     1.0
# 174790        1        1            9         Unknown    1.0     1.0
# 27405         1        1            9         Unknown    3.0     2.0
# 27406         1        1            9         Unknown   18.0     2.0
# 27413         1        1            9         Unknown   75.0     7.0
# 58668         1        1            9         Unknown    3.0     3.0
# 27419         1        1            9         Unknown    4.0     3.0
# 174801        1        1            9         Unknown    5.0     3.0
# 27422         1        1            9         Unknown    7.0     2.0
# 174802        1        1            9         Unknown    2.0     3.0
# 132632        1        1            9         Unknown    4.0     3.0
# 150397        1        1            9         Unknown    2.0     4.0
# 150396        1        1            9         Unknown    2.0     4.0
# 150395        1        1            9         Unknown   15.0     4.0
# 58672         1        1            9         Unknown    3.0     3.0
# 150390        1        1            9         Unknown    7.0     8.0
# 27437         1        1            9         Unknown    7.0    14.0
# 150389        1        1            9         Unknown    6.0     8.0
# 150388        1        1            9         Unknown    6.0     8.0
# 111919        1        1            9         Unknown    1.0     2.0
# 111918        1        1            9         Unknown    1.0     3.0
# 11801         1        1            9         Unknown    2.0     9.0
# 58678         1        1            9         Unknown    1.0     8.0
# 150371        1        1            9         Unknown    3.0     7.0
# 150369        1        1            9         Unknown   21.0     9.0
#
#         target_type               targettype_name  \
# 165889           14   Private Citizens & Property
# 150438            7       Government (Diplomatic)
# 150436            4                      Military
# 27394             4                      Military
# 27404             1                      Business
# 174789           17  Terrorists/Non-State Militia
# 174790            4                      Military
# 27405            14   Private Citizens & Property
# 27406            14   Private Citizens & Property
# 27413            14   Private Citizens & Property
# 58668             2          Government (General)
# 27419            14   Private Citizens & Property
# 174801            3                        Police
# 27422             3                        Police
# 174802           14   Private Citizens & Property
# 132632            4                      Military
# 150397            4                      Military
# 150396            4                      Military
# 150395           22       Violent Political Party
# 58672             2          Government (General)
# 150390            3                        Police
# 27437            14   Private Citizens & Property
# 150389            3                        Police
# 150388            3                        Police
# 111919           14   Private Citizens & Property
# 111918           14   Private Citizens & Property
# 11801             3                        Police
# 58678            14   Private Citizens & Property
# 150371            3                        Police
# 150369           10           Journalists & Media
#
#                                                     group  individual
# 165889                                            Unknown           1
# 150438                                            Unknown           1
# 150436                                            Taliban           1
# 27394                                    Muslim Militants           1
# 27404                       Popular Liberation Army (EPL)           1
# 174789                     Kurdistan Workers' Party (PKK)           1
# 174790                     Kurdistan Workers' Party (PKK)           1
# 27405                                             Unknown           1
# 27406                                             Unknown           1
# 27413   National Union for the Total Independence of A...           1
# 58668                                Right-Wing Militants           1
# 27419                                   Shining Path (SL)           1
# 174801                                            Taliban           1
# 27422            African National Congress (South Africa)           1
# 174802                                            Taliban           1
# 132632                                         Al-Shabaab           1
# 150397              Popular Resistance Committees (Yemen)           1
# 150396              Popular Resistance Committees (Yemen)           1
# 150395               Supporters of Abd Rabbuh Mansur Hadi           1
# 58672                                   Shining Path (SL)           1
# 150390                                            Taliban           1
# 27437                                     Sikh Extremists           1
# 150389                                            Taliban           1
# 150388                                            Taliban           1
# 111919                                   Al-Qaida in Iraq           1
# 111918                                   Al-Qaida in Iraq           1
# 11801                           Malaysian Communist Party           1
# 58678                                             Unknown           1
# 150371        Islamic State of Iraq and the Levant (ISIL)           1
# 150369        Islamic State of Iraq and the Levant (ISIL)           1

# %%
#To check how many times a particular city has occured

# %%
new_df['city'].value_counts()
# Out:
# Unknown        9785
# Baghdad        7622
# Karachi        2657
# Lima           2359
# Mosul          2270
#                ...
# Al-Sadiyah        1
# Kandikhel         1
# Pagani            1
# Mahalabiyah       1
# Mani              1
# Name: city, Length: 36674, dtype: int64

# %%
# Finding correlation of dataset

# %%
new_df.corr()
# Out:
#                  year     month       day   country    region   success  \
# year         1.000000  0.000076  0.017986 -0.135023  0.401384 -0.003593
# month        0.000076  1.000000  0.005735 -0.006313 -0.003021 -0.005418
# day          0.017986  0.005735  1.000000  0.003366  0.009841 -0.005836
# country     -0.135023 -0.006313  0.003366  1.000000  0.148597  0.000176
# region       0.401384 -0.003021  0.009841  0.148597  1.000000  0.001879
# success     -0.003593 -0.005418 -0.005836  0.000176  0.001879  1.000000
# suicide     -0.010781 -0.016254 -0.017446  0.001680 -0.000585  0.333319
# attack_type  0.074153  0.006740 -0.004208 -0.021384  0.007642  0.000429
# nkill       -0.004746  0.001780 -0.005757 -0.004934  0.007115  0.001051
# nwound      -0.013208  0.004894 -0.003035 -0.000127 -0.003515  0.000655
# target_type  0.079082 -0.000956  0.000475 -0.019703  0.041396 -0.001277
# individual  -0.028982 -0.043695 -0.040447  0.004761 -0.011583  0.123991
#
#               suicide  attack_type     nkill    nwound  target_type  \
# year        -0.010781     0.074153 -0.004746 -0.013208     0.079082
# month       -0.016254     0.006740  0.001780  0.004894    -0.000956
# day         -0.017446    -0.004208 -0.005757 -0.003035     0.000475
# country      0.001680    -0.021384 -0.004934 -0.000127    -0.019703
# region      -0.000585     0.007642  0.007115 -0.003515     0.041396
# success      0.333319     0.000429  0.001051  0.000655    -0.001277
# suicide      1.000000    -0.003910  0.000884  0.001112     0.001904
# attack_type -0.003910     1.000000  0.031953  0.008163     0.014513
# nkill        0.000884     0.031953  1.000000  0.292432     0.016503
# nwound       0.001112     0.008163  0.292432  1.000000     0.013046
# target_type  0.001904     0.014513  0.016503  0.013046     1.000000
# individual   0.371989    -0.011047 -0.002754  0.001730    -0.001109
#
#              individual
# year          -0.028982
# month         -0.043695
# day           -0.040447
# country        0.004761
# region        -0.011583
# success        0.123991
# suicide        0.371989
# attack_type   -0.011047
# nkill         -0.002754
# nwound         0.001730
# target_type   -0.001109
# individual     1.000000

# %%
#Checking the covariance of dataset

# %%
new_df.cov()
# Out:
#                    year      month        day       country     region  \
# year         175.812496   0.003398   2.098163   -201.258743  15.611960
# month          0.003398  11.479286   0.170948     -2.404321  -0.030028
# day            2.098163   0.170948  77.407488      3.329143   0.253983
# country     -201.258743  -2.404321   3.329143  12637.027755  49.001129
# region        15.611960  -0.030028   0.253983     49.001129   8.604882
# success       -0.000158  -0.000061  -0.000170      0.000066   0.000018
# suicide       -0.001423  -0.000548  -0.001528      0.001879  -0.000017
# attack_type    1.883636   0.043747  -0.070921     -4.605181   0.042944
# nkill         -0.981518   0.094048  -0.789993     -8.650247   0.325510
# nwound        -7.149885   0.676944  -1.090011     -0.581577  -0.421009
# target_type    6.977080  -0.021542   0.027799    -14.737655   0.807993
# individual    -0.010275  -0.003959  -0.009515      0.014310  -0.000909
#
#               success   suicide  attack_type       nkill       nwound  \
# year        -0.000158 -0.001423     1.883636   -0.981518    -7.149885
# month       -0.000061 -0.000548     0.043747    0.094048     0.676944
# day         -0.000170 -0.001528    -0.070921   -0.789993    -1.090011
# country      0.000066  0.001879    -4.605181   -8.650247    -0.581577
# region       0.000018 -0.000017     0.042944    0.325510    -0.421009
# success      0.000011  0.000011     0.000003    0.000054     0.000089
# suicide      0.000011  0.000099    -0.000075    0.000137     0.000452
# attack_type  0.000003 -0.000075     3.670180    0.954707     0.638494
# nkill        0.000054  0.000137     0.954707  243.230923   186.197044
# nwound       0.000089  0.000452     0.638494  186.197044  1666.770333
# target_type -0.000028  0.000126     0.185006    1.712561     3.543973
# individual   0.000011  0.000099    -0.000566   -0.001148     0.001889
#
#              target_type  individual
# year            6.977080   -0.010275
# month          -0.021542   -0.003959
# day             0.027799   -0.009515
# country       -14.737655    0.014310
# region          0.807993   -0.000909
# success        -0.000028    0.000011
# suicide         0.000126    0.000099
# attack_type     0.185006   -0.000566
# nkill           1.712561   -0.001148
# nwound          3.543973    0.001889
# target_type    44.273557   -0.000197
# individual     -0.000197    0.000715

# %% [markdown]
# # Analysis of Exploratory Data

# %%
#Visualizing the correlation of dataset

# %%
plt.figure(figsize=(15,8))
sns.heatmap(new_df.corr(),annot=True,)
plt.show()

# %%
#Visualising the covariance of dataset by using heatmap

# %%
plt.figure(figsize=(15,8))
sns.heatmap(new_df.cov(),annot=True)
plt.show()

# %%
new_df['nkill'].max()
# Out:
# 1570.0

# %%
sns.scatterplot(data=new_df,x='month',y='nkill',color='y')
plt.show()

# %%
#plotting scatter  plot for target type VS nkill

# %%
sns.scatterplot(data=new_df,x='target_type',y='nkill',hue='success')
plt.title(label='target_type VS nkill',fontdict={'size':20,'color':'magenta'})
plt.show()

# %%
plt.figure(figsize=(22,10))
sns.countplot(data=new_df,x='year',hue='success')
plt.show()

# %%
#To check how many times a value has been occured

# %%
new_df['suicide'].value_counts()
# Out:
# 1    181673
# 0        18
# Name: suicide, dtype: int64

# %%
pd.crosstab(new_df.year,new_df.region_names).plot(kind='area',figsize=(16,8))
plt.title('Terrorist activities at particular region in  several years')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.countplot(new_df['year'])
plt.title('Number of terrorist attacks by year')
plt.show()

# %%
plt.figure(figsize=(28,8))
sns.barplot(x=new_df['country_names'].value_counts()[:20].index,y=new_df['country_names'].value_counts()[:20],palette='Dark2')
plt.title('Number of terrorist attacks by Country')
plt.show()

# %%
plt.figure(figsize=(25,12))
sns.barplot(x=new_df['region_names'].value_counts()[:20].index,y=new_df['region_names'].value_counts()[:20],palette='vlag')
plt.title('Number of terrorist attacks by Region')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df['state'].value_counts()[:10].index,y=new_df['state'].value_counts()[:10],palette='viridis')
plt.title('Number of terrorist attacks by State')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df['city'].value_counts()[:15].index,y=new_df['city'].value_counts()[:15],palette='rainbow')
plt.title('Number of terrorist attacks by city')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df['month'].value_counts()[:15].index,y=new_df['month'].value_counts()[:15])
plt.title('Number of terrorist attacks by month')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=new_df['targettype_name'].value_counts()[:10].index,y=new_df['targettype_name'].value_counts()[:10],palette='flare')
plt.title('Number of terrorist attacks by Target type')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=new_df['attacktype_name'].value_counts()[:10].index,y=new_df['attacktype_name'].value_counts()[:10],palette='rocket')
plt.title('Number of terrorist attacks by Attack  type')
plt.show()
